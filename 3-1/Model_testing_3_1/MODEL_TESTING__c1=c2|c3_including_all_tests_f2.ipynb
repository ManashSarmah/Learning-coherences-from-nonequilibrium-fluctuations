# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle

# %%
plt.style.use(["science","notebook","grid"])

# %%
with open('KNN_3_1','rb') as file:
    mp = pickle.load(file)

# %%
test1=pd.read_excel('test_data_c1=c2|c3.xlsx')

# %%
test1
# Out:
#            c1        c2        c3
# 0    0.825931  0.825931  0.870374
# 1    0.834376  0.834376  0.975062
# 2    0.916691  0.916691  0.944277
# 3    0.866426  0.866426  0.804551
# 4    0.778904  0.778904  0.823971
# ..        ...       ...       ...
# 995  0.995163  0.995163  0.962823
# 996  0.889150  0.889150  0.819299
# 997  0.794226  0.794226  0.893224
# 998  0.849862  0.849862  0.794056
# 999  0.965953  0.965953  0.809623
#
# [1000 rows x 3 columns]

# %%
p_test1=mp.predict_proba(test1.values)

# %%
c1t1=p_test1[:,0]
c2t1=p_test1[:,1]
c3t1=p_test1[:,2]
c4t1=p_test1[:,3]

# %%
y1t1=len(c1t1[c1t1==1])
y2t1=len(c2t1[c2t1==1])
y3t1=len(c3t1[c3t1==1])
y4t1=len(c4t1[c4t1==1])

y5t1=len(c1t1[(c1t1!=1) & (c1t1!=0)])
y6t1=len(c2t1[(c2t1!=1) & (c2t1!=0)])
y7t1=len(c3t1[(c3t1!=1) & (c3t1!=0)])
y8t1=len(c4t1[(c4t1!=1) & (c4t1!=0)])

# %%
x1t1='$\mathcal{P}(p_h)$=1\nclass 0'
x2t1='$\mathcal{P}(p_h)$=1\nclass 1'
x3t1='$\mathcal{P}(p_h)$=1\nclass 2'
x4t1='$\mathcal{P}(p_h)$=1\nclass 3'

x5t1='$\mathcal{P}(p_h)$<1\nclass 0'
x6t1='$\mathcal{P}(p_h)$<1\nclass 1'
x7t1='$\mathcal{P}(p_h)$<1\nclass 2'
x8t1='$\mathcal{P}(p_h)$<1\nclass 3'

# %%
x_lab_t1=x1t1,x2t1,x3t1,x4t1,x5t1,x6t1,x7t1,x8t1
y_lab_t1=y1t1,y2t1,y3t1,y4t1,y5t1,y6t1,y7t1,y8t1

# %%
plt.figure(figsize=(6,3))
plt.scatter(x_lab_t1,y_lab_t1)
plt.vlines(x = x_lab_t1[0],ymin=-0.001, ymax = y_lab_t1[0], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[0],y_lab_t1[0], f"{y_lab_t1[0]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[1],ymin=-0.001, ymax = y_lab_t1[1], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[1],y_lab_t1[1], f"{y_lab_t1[1]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[2],ymin=-0.001, ymax = y_lab_t1[2], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[2],y_lab_t1[2], f"{y_lab_t1[2]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[3],ymin=-0.001, ymax = y_lab_t1[3], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[3],y_lab_t1[3], f"{y_lab_t1[3]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[4],ymin=-0.001, ymax = y_lab_t1[4], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[4],y_lab_t1[4], f"{y_lab_t1[4]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[5],ymin=-0.001, ymax = y_lab_t1[5], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[5],y_lab_t1[5], f"{y_lab_t1[5]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[6],ymin=-0.001, ymax = y_lab_t1[6], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[6],y_lab_t1[6], f"{y_lab_t1[6]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[7],ymin=-0.001, ymax = y_lab_t1[7], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[7],y_lab_t1[7], f"{y_lab_t1[7]}", ha='left', va='bottom',fontsize=12)
plt.annotate('$C^{{(1)}}=C^{{(2)}},C^{{(3)}}$', xy=(0.5, 0.7), xycoords='axes fraction', fontsize=15, bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="black"))

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(top=900,bottom=0.01)
plt.ylabel('Occurances',fontsize=10)
# Out:
# Text(0, 0.5, 'Occurances')

# %%
c1t1[(c1t1>0)& (c1t1<1)]
# Out:
# array([0.779903  , 0.55382758, 0.5548786 , 0.66534437, 0.66804432,
#        0.21661571, 0.3299398 ])

# %%
test1['class0']= p_test1.T[0]
test1['class1']= p_test1.T[1]
test1['class2']= p_test1.T[2]
test1['class3']= p_test1.T[3]

# %%
test1.c3.values[np.where(test1.class0.values==1)].shape
# Out:
# (485,)

# %%
test1.c3.values[np.where(test1.class3.values==1)].shape
# Out:
# (429,)

# %%
plt.figure(figsize=(4,3))
plt.hist(test1.c3.values[np.where(test1.class0.values==1)],histtype='step',label='$C^{(3)}$ values\nfor class0')
plt.hist(test1.c1.values[np.where(test1.class0.values==1)],histtype='step',label='$C^{(1)}$ values\nfor class0')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test1.c3.values[np.where(test1.class3.values==1)],histtype='step',label='$C^{(3)}$ values\nfor class3')
plt.hist(test1.c1.values[np.where(test1.class3.values==1)],histtype='step',label='$C^{(1)}$ values\nfor class3')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 3))

# Histograms for class 0
plt.hist(test1.c1.values[np.where(test1.class0.values == 1)], histtype='step',color='b', label='$C^{(2)}(0)$')
plt.hist(test1.c3.values[np.where(test1.class0.values == 1)],histtype='step',color='r',label='$C^{(3)}(0)$')


# Histograms for class 3
plt.hist(test1.c1.values[np.where(test1.class3.values == 1)], histtype='step',linestyle='dotted',color='b', label='$C^{(2)}(3)$')
plt.hist(test1.c3.values[np.where(test1.class3.values == 1)], histtype='step',linestyle='dotted',color='r',label='$C^{(3)}(3)$')
plt.xlabel('Distribution')
plt.ylabel('Occurances')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test1.c3.values[np.where(test1.class2.values==1)],histtype='step',label='$C^{(3)}$ values\nfor class2')
plt.hist(test1.c1.values[np.where(test1.class2.values==1)],histtype='step',label='$C^{(1)}$ values\nfor class2')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test1.c3.values[np.where(test1.class2.values==1)],histtype='step',label='$C^{(3)}$ values\nfor class2')
plt.hist(test1.c1.values[np.where(test1.class2.values==1)],histtype='step',label='$C^{(1)}$ values\nfor class2')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
np.min(test1.c1.values[np.where(test1.class3.values==1)])
# Out:
# 0.874991780552674

# %%
test2=pd.read_excel('test_data_c1>c2|c3.xlsx')

# %%
test2
# Out:
#            c1        c2        c3
# 0    1.007221  0.891411  0.870374
# 1    0.991283  0.915358  0.975062
# 2    0.962293  0.809774  0.944277
# 3    1.030437  1.022043  0.804551
# 4    0.879368  0.871134  0.823971
# ..        ...       ...       ...
# 995  0.985836  0.830898  0.962823
# 996  0.973772  0.923148  0.819299
# 997  0.948139  0.873270  0.893224
# 998  1.037824  1.018304  0.794056
# 999  0.916552  0.906251  0.809623
#
# [1000 rows x 3 columns]

# %%
p_test2=mp.predict_proba(test2.values)

# %%
c1t2=p_test2[:,0]
c2t2=p_test2[:,1]
c3t2=p_test2[:,2]
c4t2=p_test2[:,3]

# %%
y1t2=len(c1t2[c1t2==1])
y2t2=len(c2t2[c2t2==1])
y3t2=len(c3t2[c3t2==1])
y4t2=len(c4t2[c4t2==1])

y5t2=len(c1t2[(c1t2!=1) & (c1t2!=0)])
y6t2=len(c2t2[(c2t2!=1) & (c2t2!=0)])
y7t2=len(c3t2[(c3t2!=1) & (c3t2!=0)])
y8t2=len(c4t2[(c4t2!=1) & (c4t2!=0)])

# %%
y_lab_t2=y1t2,y2t2,y3t2,y4t2,y5t2,y6t2,y7t2,y8t2

# %%
plt.figure(figsize=(6,3))
plt.scatter(x_lab_t1,y_lab_t2)
plt.vlines(x = x_lab_t1[0],ymin=-0.001, ymax = y_lab_t2[0], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[0],y_lab_t2[0], f"{y_lab_t2[0]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[1],ymin=-0.001, ymax = y_lab_t2[1], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[1],y_lab_t2[1], f"{y_lab_t2[1]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[2],ymin=-0.001, ymax = y_lab_t2[2], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[2],y_lab_t2[2], f"{y_lab_t2[2]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[3],ymin=-0.001, ymax = y_lab_t2[3], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[3],y_lab_t2[3], f"{y_lab_t2[3]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[4],ymin=-0.001, ymax = y_lab_t2[4], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[4],y_lab_t2[4], f"{y_lab_t2[4]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[5],ymin=-0.001, ymax = y_lab_t2[5], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[5],y_lab_t2[5], f"{y_lab_t2[5]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[6],ymin=-0.001, ymax = y_lab_t2[6], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[6],y_lab_t2[6], f"{y_lab_t2[6]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[7],ymin=-0.001, ymax = y_lab_t2[7], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[7],y_lab_t2[7], f"{y_lab_t2[7]}", ha='left', va='bottom',fontsize=12)
plt.annotate('$C^{{(1)}}>C^{{(2)}}$,$C^{{(3)}}$', xy=(0.4, 0.5), xycoords='axes fraction', fontsize=15, bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="black"))

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(top=950,bottom=0.01)
plt.ylabel('Occurances',fontsize=10)
# Out:
# Text(0, 0.5, 'Occurances')

# %%
test2['class0']= p_test2.T[0]
test2['class1']= p_test2.T[1]
test2['class2']= p_test2.T[2]
test2['class3']= p_test2.T[3]

# %%
test2.c1.values[np.where(test2.class0.values==1)].shape
# Out:
# (570,)

# %%
test2.c3.values[np.where(test2.class3.values==1)].shape
# Out:
# (184,)

# %%
plt.figure(figsize=(4,3))
plt.hist(test2.c1.values[np.where(test2.class0.values==1)],histtype='step',label='$C^{(1)}$ values\nfor class0')
plt.hist(test2.c2.values[np.where(test2.class0.values==1)],histtype='step',label='$C^{(2)}$ values\nfor class0')
plt.hist(test2.c3.values[np.where(test2.class0.values==1)],histtype='step',label='$C^{(3)}$ values\nfor class0')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test2.c1.values[np.where(test2.class0.values==1)],histtype='step',color='r',label='$C^{(1)}(0)$')
plt.hist(test2.c2.values[np.where(test2.class0.values==1)],histtype='step',color='g',label='$C^{(2)}(0)$')
plt.hist(test2.c3.values[np.where(test2.class0.values==1)],histtype='step',color='b',label='$C^{(3)}(0)$')
plt.hist(test2.c1.values[np.where(test2.class3.values==1)],histtype='step',color='r',linestyle='dotted',label='$C^{(1)}(3)$')
plt.hist(test2.c2.values[np.where(test2.class3.values==1)],histtype='step',color='g',linestyle='dotted',label='$C^{(2)}(3)$')
plt.hist(test2.c3.values[np.where(test2.class3.values==1)],histtype='step',color='b',linestyle='dotted',label='$C^{(3)}(3)$')
plt.xlabel('Distribution')
plt.ylabel('Occurances')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Distribution')
plt.ylabel('Occurances')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',fontsize=14)
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test2.c1.values[np.where(test2.class1.values==1)],color='r',histtype='step',label='$C^{(1)}(1)$')
plt.hist(test2.c2.values[np.where(test2.class1.values==1)],color='g',histtype='step',label='$C^{(2)}(1)$')
plt.hist(test2.c3.values[np.where(test2.class1.values==1)],color='b',histtype='step',label='$C^{(3)}(1)$')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('Distribution')
plt.ylabel('Occurances')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',fontsize=14)
plt.show()
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test2.c1.values[np.where(test2.class2.values==1)],color='r',histtype='step',label='$C^{(1)}(2)$')
plt.hist(test2.c2.values[np.where(test2.class2.values==1)],color='g',histtype='step',label='$C^{(2)}(2)$')
plt.hist(test2.c3.values[np.where(test2.class2.values==1)],color='b',histtype='step',label='$C^{(3)}(2)$')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('Distribution')
plt.ylabel('Occurances')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',fontsize=14)
plt.show()
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test2.c1.values[np.where(test2.class3.values==1)],histtype='step',label='$C^{(1)}$ values\nfor class3')
# plt.hist(test2.c2.values[np.where(test2.class3.values==1)],histtype='step',label='$C^{(2)}$ values\nfor class3')
# plt.hist(test2.c3.values[np.where(test2.class3.values==1)],histtype='step',label='$C^{(3)}$ values\nfor class3')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#reading the data file
test3=pd.read_excel('test_data_c1<c2|c3.xlsx')
##################################


#predicting using the test data
p_test3=mp.predict_proba(test3.values)
###############################

#categorising classes into columns
c1t3=p_test3[:,0]
c2t3=p_test3[:,1]
c3t3=p_test3[:,2]
c4t3=p_test3[:,3]
###############################

#Defining y-corrdinates
y1t3=len(c1t3[c1t3==1])
y2t3=len(c2t3[c2t3==1])
y3t3=len(c3t3[c3t3==1])
y4t3=len(c4t3[c4t3==1])

y5t3=len(c1t3[(c1t3!=1) & (c1t3!=0)])
y6t3=len(c2t3[(c2t3!=1) & (c2t3!=0)])
y7t3=len(c3t3[(c3t3!=1) & (c3t3!=0)])
y8t3=len(c4t3[(c4t3!=1) & (c4t3!=0)])
################################

# x-corrdinates remains same

#putting y-corrdinates into an array
y_lab_t3=y1t3,y2t3,y3t3,y4t3,y5t3,y6t3,y7t3,y8t3
##################################

#Plotting the results
plt.figure(figsize=(6,3))
plt.scatter(x_lab_t1,y_lab_t3)
plt.vlines(x = x_lab_t1[0],ymin=-0.001, ymax = y_lab_t3[0], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[0],y_lab_t3[0], f"{y_lab_t3[0]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[1],ymin=-0.001, ymax = y_lab_t3[1], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[1],y_lab_t3[1], f"{y_lab_t3[1]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[2],ymin=-0.001, ymax = y_lab_t3[2], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[2],y_lab_t3[2], f"{y_lab_t3[2]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[3],ymin=-0.001, ymax = y_lab_t3[3], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[3],y_lab_t3[3], f"{y_lab_t3[3]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[4],ymin=-0.001, ymax = y_lab_t3[4], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[4],y_lab_t3[4], f"{y_lab_t3[4]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[5],ymin=-0.001, ymax = y_lab_t3[5], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[5],y_lab_t3[5], f"{y_lab_t3[5]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[6],ymin=-0.001, ymax = y_lab_t3[6], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[6],y_lab_t3[6], f"{y_lab_t3[6]}", ha='left', va='bottom',fontsize=12)

plt.vlines(x = x_lab_t1[7],ymin=-0.001, ymax = y_lab_t3[7], color = 'r',
            label = 'axvline - % of full height')
plt.text(x_lab_t1[7],y_lab_t3[7], f"{y_lab_t3[7]}", ha='left', va='bottom',fontsize=12)
plt.annotate('$C^{{(1)}}<C^{{(2)}}$, $C^{{(3)}}$', xy=(0.6, 0.5), xycoords='axes fraction', fontsize=15, bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="black"))

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(top=1000,bottom=0.01)
plt.ylabel('Occurances',fontsize=10)
# Out:
# Text(0, 0.5, 'Occurances')

# %%
plt.figure(figsize=(5,3))
x=np.array([0,2,4,6,8,10,12,14])*2
plt.bar(x,y_lab_t1,color='floralwhite',width=1.0,edgecolor='black')
plt.bar(x+1,y_lab_t2,color='turquoise',width=1.0,edgecolor='black')
plt.bar(x+2,y_lab_t3,color='greenyellow',width=1.0,edgecolor='black')

plt.annotate('class 0', xy=(1, y_lab_t1[0]),xytext=(1, y_lab_t1[0]+250), rotation=90,ha='center',fontsize=15)
plt.annotate('class 1', xy=(5, y_lab_t1[1]), xytext=(5, y_lab_t1[1]+150),rotation=90,ha='center',fontsize=15)
plt.annotate('class 2', xy=(9, y_lab_t1[2]), xytext=(9, y_lab_t1[2]+60),rotation=90,ha='center',fontsize=15)
plt.annotate('class 3', xy=(13, y_lab_t2[3]),xytext=(13, y_lab_t2[3]+500), rotation=90,ha='center',fontsize=15)
plt.annotate('class 0', xy=(17, y_lab_t2[4]),xytext=(17, y_lab_t2[4]+30), rotation=90,ha='center',fontsize=15)
plt.annotate('class 1', xy=(21, y_lab_t2[5]),xytext=(21, y_lab_t2[5]+30), rotation=90,ha='center',fontsize=15)
plt.annotate('class 2', xy=(25, y_lab_t3[6]),xytext=(25, y_lab_t3[6]+30), rotation=90,ha='center',fontsize=15)
plt.annotate('class 3', xy=(29, y_lab_t3[7]),xytext=(29, y_lab_t3[7]+30), rotation=90,ha='center',fontsize=15)

plt.xticks(x+1.5,(('$\\mathcal{P}(p_h)$=1',
 '$\\mathcal{P}(p_h)$=1',
 '$\\mathcal{P}(p_h)$=1',
 '$\\mathcal{P}(p_h)$=1',
 '$\\mathcal{P}(p_h)$<1',
 '$\\mathcal{P}(p_h)$<1',
 '$\\mathcal{P}(p_h)$<1',
 '$\\mathcal{P}(p_h)$<1')),fontstyle='oblique',rotation=90,fontsize=15)
plt.ylabel('Occurances',fontsize=15)
plt.yticks(fontsize=15)
plt.ylim(top=1200)
plt.annotate('$C^{{(1)}}=C^{{(2)}},C^{{(3)}}$', xy=(0.6,0.9 ), xycoords='axes fraction', fontsize=10, bbox=dict(boxstyle="round,pad=0.3", fc="floralwhite", ec="black"))
plt.annotate('$C^{{(1)}}>C^{{(2)}},C^{{(3)}}$', xy=(0.6,0.8), xycoords='axes fraction', fontsize=10, bbox=dict(boxstyle="round,pad=0.3", fc="turquoise", ec="black"))
plt.annotate('$C^{{(1)}}<C^{{(2)}},C^{{(3)}}$', xy=(0.6,0.7 ), xycoords='axes fraction', fontsize=10, bbox=dict(boxstyle="round,pad=0.3", fc='greenyellow', ec="black"))
plt.grid(visible=False, axis="x")  # remove only x-axis grid lines
plt.tick_params(axis='x', which='both', bottom=False, top=False)
# plt.savefig('f2.jpeg',dpi=300)

# %%
test3['class0']= p_test3.T[0]
test3['class1']= p_test3.T[1]
test3['class2']= p_test3.T[2]
test3['class3']= p_test3.T[3]

# %%
test3.c1.values[np.where(test3.class0.values==1)].shape
# Out:
# (143,)

# %%
test3.c3.values[np.where(test3.class3.values==1)].shape
# Out:
# (805,)

# %%
plt.figure(figsize=(4,3))
plt.hist(test3.c1.values[np.where(test3.class0.values==1)],histtype='step',label='$C^{(1)}$ values\nfor class0')
plt.hist(test3.c2.values[np.where(test3.class0.values==1)],histtype='step',label='$C^{(2)}$ values\nfor class0')
plt.hist(test3.c3.values[np.where(test3.class0.values==1)],histtype='step',label='$C^{(3)}$ values\nfor class0')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test3.c1.values[np.where(test3.class3.values==1)],histtype='step',label='$C^{(1)}$ values\nfor class3')
plt.hist(test3.c2.values[np.where(test3.class3.values==1)],histtype='step',label='$C^{(2)}$ values\nfor class3')
plt.hist(test3.c3.values[np.where(test3.class3.values==1)],histtype='step',label='$C^{(3)}$ values\nfor class3')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.hist(test3.c1.values[np.where(test3.class0.values==1)],histtype='step',color='r',label='$C^{(1)}(0)$')
plt.hist(test3.c2.values[np.where(test3.class0.values==1)],histtype='step',color='g',label='$C^{(2)}(0)$')
plt.hist(test3.c3.values[np.where(test3.class0.values==1)],histtype='step',color='b',label='$C^{(3)}(0)$')
plt.hist(test3.c1.values[np.where(test3.class3.values==1)],histtype='step',color='r',linestyle='dotted',label='$C^{(1)}(3)$')
plt.hist(test3.c2.values[np.where(test3.class3.values==1)],histtype='step',color='g',linestyle='dotted',label='$C^{(2)}(3)$')
plt.hist(test3.c3.values[np.where(test3.class3.values==1)],histtype='step',color='b',linestyle='dotted',label='$C^{(3)}(3)$')

plt.xlabel('Distribution')
plt.ylabel('Occurances')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',fontsize=14)
plt.show()
